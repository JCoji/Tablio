# %% [markdown]
# # Validation Set Evaluation — v2 Model (GuitarSetIsolatedClean-trained)
# Runs demucs -> tab CRNN pipeline over the clean synthetic MusDB18 + GuitarSet mix dataset.
# Uses `hyperparam_set_v2` run_2 (Higher Dropout 0.55), which was trained on Demucs-extracted
# guitar stems from clean mixes (`GuitarSetIsolatedClean`).
#
# Dataset Dir: `guitarset_demucs/guitarset_mixed_dataset_clean/val/`

# %%
import sys, os
from pathlib import Path

REPO_ROOT = Path(os.getcwd())
SRC_DIR   = REPO_ROOT / 'src'
for p in [str(REPO_ROOT), str(SRC_DIR)]:
    if p not in sys.path:
        sys.path.insert(0, p)

# %%
import torch
import numpy as np
import jams
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

import config
from src.run_pipeline import PipelineState, Node, run_pipeline
from src.nodes import stem_extraction, load_model, predict
from evaluation.metrics import calculate_note_level_metrics, calculate_onset_event_metrics

# %%
# ── Configuration ──────────────────────────────────────────────────────────────
VAL_DIR       = REPO_ROOT / 'guitarset_demucs' / 'guitarset_mixed_dataset_augmented' / 'val'
ARTIFACTS_DIR = REPO_ROOT / 'hyperparam_set_v2'
ONSET_THRESH  = config.DEFAULT_TDR_THRESHOLD   # 0.5

# Auto-detect device
if torch.backends.mps.is_available():
    DEVICE = 'mps'
elif torch.cuda.is_available():
    DEVICE = 'cuda'
else:
    DEVICE = 'cpu'
print(f'Device: {DEVICE}')

# Open-string MIDI pitches: string 0 = low E (40), ..., string 5 = high e (64)
OPEN_STRING_PITCHES = config.OPEN_STRING_PITCHES_MIDI  # {0:40,1:45,2:50,3:55,4:59,5:64}
# Out:
# Device: mps

# %%
# ── Select model run ───────────────────────────────────────────────────────────
runs = sorted([d for d in ARTIFACTS_DIR.iterdir()
               if d.is_dir() and (d / 'best_model.pth').exists()])

print('Available runs:')
for i, r in enumerate(runs):
    print(f'  [{i}] {r.name}')
# Out:
# Available runs:
#   [0] run_1_Baseline_run72_re-run_with_new_aug_augEnabled
#   [1] run_2_Test_Higher_Dropout_0.55_augEnabled
#   [2] run_3_Test_More_Patient_Scheduler_12_augEnabled
#   [3] run_4_Test_Higher_OnsetLossWeight_10_augEnabled
#   [4] run_5_Test_Higher_Dropout_and_Patient_Scheduler_augEnabled

# %%
RUN_IDX = 1   # run_2_Test_Higher_Dropout_0.55 — best val_tdr_f1 in v2 (0.6798)

run_dir = runs[RUN_IDX]
print(f'Loading: {run_dir.name}')

# Build a state just to load the model once — reused for all tracks
_init_state = PipelineState(
    input_path=Path('/dev/null'),
    artifacts_dir=ARTIFACTS_DIR,
    extras={'device': DEVICE, 'run_name': run_dir.name},
)
_init_state = load_model(_init_state)
shared_model = _init_state.model
print('Model loaded.')
# Out:
# Loading: run_2_Test_Higher_Dropout_0.55_augEnabled
# --- Próba załadowania modelu z pliku: best_model.pth ---
# Odtworzone parametry inicjalizacyjne: {'num_frames_rnn_input_dim': 1280, 'rnn_type': 'GRU', 'rnn_hidden_size': 768, 'rnn_layers': 2, 'rnn_dropout': 0.55, 'rnn_bidirectional': True}
# Ładowanie wag na urządzenie: mps
# Model pomyślnie załadowany i przeniesiony na urządzenie: mps
# Model loaded.

# %%
def parse_gt_notes_from_jams(jams_path):
    """Return list of GT note dicts from a GuitarSet JAMS file.
    Each annotation in note_midi corresponds to one string (index 0-5).
    obs.time and obs.duration are plain floats (seconds).
    """
    j = jams.load(str(jams_path))
    note_anns = j.search(namespace='note_midi')
    notes = []
    for string_idx, ann in enumerate(note_anns):
        open_pitch = OPEN_STRING_PITCHES[string_idx]
        for obs in ann.data:
            pitch = int(round(obs.value))
            fret  = pitch - open_pitch
            if 0 <= fret <= config.MAX_FRETS:
                notes.append({
                    'start_time': float(obs.time),
                    'end_time':   float(obs.time + obs.duration),
                    'pitch_midi': pitch,
                    'string':     string_idx,
                    'fret':       fret,
                })
    return notes

# %%
def gt_notes_to_raw_tensor(gt_notes):
    """Convert GT note list to the (N,4) tensor format expected by metrics.py."""
    if not gt_notes:
        return torch.zeros((0, 4))
    rows = [[n['start_time'], n['end_time'], n['string'], n['fret']] for n in gt_notes]
    return torch.tensor(rows, dtype=torch.float32)

# %%
# ── Run evaluation over all val tracks ────────────────────────────────────────
PIPELINE_NODES = [
    Node("stem_extraction", stem_extraction),
    Node("predict",         predict),
]

wav_files = sorted(VAL_DIR.glob('*.wav'))
print(f'Evaluating {len(wav_files)} tracks...')

results = []

for wav_path in tqdm(wav_files):
    track_id  = wav_path.stem
    jams_path = wav_path.with_suffix('.jams')

    if not jams_path.exists():
        print(f'  [SKIP] No JAMS for {track_id}')
        continue

    try:
        state = PipelineState(
            input_path=wav_path,
            artifacts_dir=ARTIFACTS_DIR,
            model=shared_model,   # reuse loaded model — no reload per track
            extras={'device': DEVICE, 'run_name': run_dir.name},
        )
        state = run_pipeline(state, PIPELINE_NODES)

        pred_notes = state.predicted_notes or []
        gt_notes   = parse_gt_notes_from_jams(jams_path)
        gt_raw     = gt_notes_to_raw_tensor(gt_notes)

        tdr   = calculate_note_level_metrics(pred_notes, gt_raw)
        onset = calculate_onset_event_metrics(pred_notes, gt_raw)

        results.append({
            'track':           track_id,
            'n_gt_notes':      len(gt_notes),
            'n_pred_notes':    len(pred_notes),
            'tdr_precision':   tdr['tdr_precision'],
            'tdr_recall':      tdr['tdr_recall'],
            'tdr_f1':          tdr['tdr_f1'],
            'onset_precision': onset['onset_precision_event'],
            'onset_recall':    onset['onset_recall_event'],
            'onset_f1':        onset['onset_f1_event'],
        })

    except Exception as e:
        print(f'  [ERROR] {track_id}: {e}')

df = pd.DataFrame(results)
print(f'\nDone. {len(df)} tracks evaluated.')
# Out:
# Evaluating 72 tracks...
#   0%|          | 0/72 [00:00<?, ?it/s]
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 00_BN1-129-Eb_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/00_BN1-129-Eb_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/00_BN1-129-Eb_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/00_BN3-119-G_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 00_BN3-154-E_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/00_BN3-154-E_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 00_Funk1-97-C_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/00_Funk1-97-C_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 00_Jazz1-130-D_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/00_Jazz1-130-D_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 00_SS1-100-C#_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/00_SS1-100-C#_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 00_SS1-100-C#_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/00_SS1-100-C#_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 00_SS2-107-Ab_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/00_SS2-107-Ab_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/01_BN1-129-Eb_comp.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 01_BN1-147-Gb_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/01_BN1-147-Gb_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 01_BN3-154-E_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/01_BN3-154-E_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 01_BN3-154-E_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/01_BN3-154-E_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 01_Funk1-114-Ab_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/01_Funk1-114-Ab_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/01_Jazz1-130-D_comp.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 01_Jazz2-187-F#_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/01_Jazz2-187-F#_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 01_Rock3-117-Bb_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/01_Rock3-117-Bb_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_BN1-129-Eb_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_BN1-129-Eb_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_BN1-147-Gb_comp.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_BN1-147-Gb_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_BN1-147-Gb_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_BN2-131-B_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_BN2-131-B_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_BN2-166-Ab_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_BN2-166-Ab_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_Funk1-114-Ab_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_Funk1-114-Ab_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_Funk1-97-C_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_Funk1-97-C_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_Funk2-108-Eb_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_Funk3-98-A_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_Funk3-98-A_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_Jazz3-150-C_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_Rock2-142-D_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_Rock2-142-D_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_SS1-100-C#_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_SS1-100-C#_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_SS1-68-E_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_SS1-68-E_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 02_SS2-88-F_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_SS2-88-F_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/02_SS3-98-C_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_BN3-119-G_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_BN3-119-G_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_BN3-119-G_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_BN3-119-G_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_BN3-154-E_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_BN3-154-E_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_BN3-154-E_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_BN3-154-E_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_Funk2-119-G_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_Funk2-119-G_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_Funk3-98-A_comp.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_Rock1-90-C#_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_Rock1-90-C#_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_Rock1-90-C#_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_Rock1-90-C#_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_Rock2-85-F_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_Rock2-85-F_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_Rock3-117-Bb_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_Rock3-117-Bb_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_Rock3-117-Bb_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_Rock3-117-Bb_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_SS1-100-C#_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_SS1-100-C#_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_SS2-107-Ab_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_SS2-107-Ab_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_SS2-88-F_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_SS2-88-F_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 03_SS3-98-C_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/03_SS3-98-C_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_BN1-129-Eb_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 04_BN3-119-G_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_BN3-119-G_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 04_Funk2-108-Eb_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_Funk2-108-Eb_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 04_Funk2-119-G_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_Funk2-119-G_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 04_Funk2-119-G_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_Funk2-119-G_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_Funk3-112-C#_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_Jazz3-150-C_comp.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 04_Rock1-130-A_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_Rock1-130-A_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 04_Rock1-90-C#_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_Rock1-90-C#_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 04_Rock3-148-C_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_Rock3-148-C_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 04_SS2-107-Ab_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_SS2-107-Ab_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 04_SS2-88-F_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_SS2-88-F_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/04_SS3-98-C_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_BN1-129-Eb_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 05_BN2-131-B_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_BN2-131-B_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_BN3-119-G_comp.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 05_Funk1-114-Ab_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_Funk1-114-Ab_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 05_Funk2-119-G_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_Funk2-119-G_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 05_Funk3-98-A_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_Funk3-98-A_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 05_Jazz2-110-Bb_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_Jazz2-110-Bb_comp.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 05_Jazz2-110-Bb_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_Jazz2-110-Bb_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Using cached stem: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_Rock1-130-A_solo.wav
# [RUN]  stem_extraction
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 05_Rock3-148-C_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_Rock3-148-C_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 05_SS3-84-Bb_solo.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_SS3-84-Bb_solo.wav
# [RUN]  predict
# INFO:stem_extraction:Using device: mps
# INFO:stem_extraction:Loading model: htdemucs_6s
# [RUN]  stem_extraction
# INFO:stem_extraction:Separating stems for: 05_SS3-98-C_comp.wav
# INFO:stem_extraction:Stem saved to: /Users/jonathanc/dev/Tablio/output/extracted_guitar_stems/05_SS3-98-C_comp.wav
# [RUN]  predict
#
# Done. 72 tracks evaluated.

# %%
# ── Summary statistics ─────────────────────────────────────────────────────────
metric_cols = ['tdr_precision','tdr_recall','tdr_f1','onset_precision','onset_recall','onset_f1']
summary = df[metric_cols].agg(['mean','median','std']).T
summary.columns = ['mean','median','std']
print(f'Run: {run_dir.name}\n')
print(summary.to_string(float_format='{:.3f}'.format))
# Out:
# Run: run_2_Test_Higher_Dropout_0.55_augEnabled
#
#                  mean  median   std
# tdr_precision   0.788   0.834 0.139
# tdr_recall      0.725   0.765 0.190
# tdr_f1          0.750   0.803 0.166
# onset_precision 0.889   0.913 0.091
# onset_recall    0.668   0.695 0.208
# onset_f1        0.746   0.788 0.163

# %%
# ── Per-track table ────────────────────────────────────────────────────────────
df.set_index('track')[metric_cols].sort_values('tdr_f1', ascending=False).style.format('{:.3f}').background_gradient(cmap='RdYlGn', axis=0)
# Out:
# <style type="text/css">
# #T_2dc56_row0_col0 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
# }
# #T_2dc56_row0_col1 {
#   background-color: #036e3a;
#   color: #f1f1f1;
# }
# #T_2dc56_row0_col2, #T_2dc56_row0_col4, #T_2dc56_row0_col5, #T_2dc56_row1_col2, #T_2dc56_row2_col0, #T_2dc56_row3_col1, #T_2dc56_row3_col4, #T_2dc56_row4_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2dc56_row0_col3, #T_2dc56_row6_col1, #T_2dc56_row40_col3 {
#   background-color: #17934e;
#   color: #f1f1f1;
# }
# #T_2dc56_row1_col0, #T_2dc56_row1_col3, #T_2dc56_row2_col3, #T_2dc56_row5_col5 {
#   background-color: #04703b;
#   color: #f1f1f1;
# }
# #T_2dc56_row1_col1, #T_2dc56_row4_col0, #T_2dc56_row14_col1 {
#   background-color: #0a7b41;
#   color: #f1f1f1;
# }
# #T_2dc56_row1_col4, #T_2dc56_row63_col4 {
#   background-color: #eff8aa;
#   color: #000000;
# }
# #T_2dc56_row1_col5 {
#   background-color: #a7d96b;
#   color: #000000;
# }
# #T_2dc56_row2_col1, #T_2dc56_row9_col2, #T_2dc56_row10_col2, #T_2dc56_row11_col2 {
#   background-color: #0f8446;
#   color: #f1f1f1;
# }
# #T_2dc56_row2_col2, #T_2dc56_row3_col2 {
#   background-color: #026c39;
#   color: #f1f1f1;
# }
# #T_2dc56_row2_col4, #T_2dc56_row8_col4 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
# }
# #T_2dc56_row2_col5 {
#   background-color: #016a38;
#   color: #f1f1f1;
# }
# #T_2dc56_row3_col0, #T_2dc56_row12_col1, #T_2dc56_row13_col2, #T_2dc56_row18_col0, #T_2dc56_row18_col5, #T_2dc56_row22_col5 {
#   background-color: #15904c;
#   color: #f1f1f1;
# }
# #T_2dc56_row3_col3, #T_2dc56_row8_col3, #T_2dc56_row17_col0, #T_2dc56_row20_col4, #T_2dc56_row26_col0, #T_2dc56_row33_col2, #T_2dc56_row52_col5 {
#   background-color: #57b65f;
#   color: #f1f1f1;
# }
# #T_2dc56_row3_col5, #T_2dc56_row4_col2 {
#   background-color: #07753e;
#   color: #f1f1f1;
# }
# #T_2dc56_row4_col1, #T_2dc56_row6_col0, #T_2dc56_row7_col0, #T_2dc56_row45_col3 {
#   background-color: #118848;
#   color: #f1f1f1;
# }
# #T_2dc56_row4_col4 {
#   background-color: #fdad60;
#   color: #000000;
# }
# #T_2dc56_row4_col5, #T_2dc56_row23_col5, #T_2dc56_row63_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_2dc56_row5_col0, #T_2dc56_row14_col2, #T_2dc56_row15_col2, #T_2dc56_row15_col5, #T_2dc56_row26_col5, #T_2dc56_row35_col3, #T_2dc56_row53_col3 {
#   background-color: #16914d;
#   color: #f1f1f1;
# }
# #T_2dc56_row5_col1, #T_2dc56_row9_col3, #T_2dc56_row21_col5 {
#   background-color: #128a49;
#   color: #f1f1f1;
# }
# #T_2dc56_row5_col2, #T_2dc56_row6_col2, #T_2dc56_row8_col5 {
#   background-color: #0d8044;
#   color: #f1f1f1;
# }
# #T_2dc56_row5_col3, #T_2dc56_row7_col1, #T_2dc56_row30_col5, #T_2dc56_row34_col3 {
#   background-color: #18954f;
#   color: #f1f1f1;
# }
# #T_2dc56_row5_col4 {
#   background-color: #08773f;
#   color: #f1f1f1;
# }
# #T_2dc56_row6_col3, #T_2dc56_row16_col2, #T_2dc56_row17_col1, #T_2dc56_row17_col2, #T_2dc56_row24_col0, #T_2dc56_row29_col0, #T_2dc56_row41_col5 {
#   background-color: #1e9a51;
#   color: #f1f1f1;
# }
# #T_2dc56_row6_col4, #T_2dc56_row9_col5, #T_2dc56_row10_col4, #T_2dc56_row61_col1, #T_2dc56_row68_col3 {
#   background-color: #e6f59d;
#   color: #000000;
# }
# #T_2dc56_row6_col5, #T_2dc56_row10_col5, #T_2dc56_row19_col4, #T_2dc56_row30_col3 {
#   background-color: #a5d86a;
#   color: #000000;
# }
# #T_2dc56_row7_col2, #T_2dc56_row8_col2, #T_2dc56_row10_col1, #T_2dc56_row12_col5, #T_2dc56_row13_col1, #T_2dc56_row16_col4, #T_2dc56_row30_col4 {
#   background-color: #0e8245;
#   color: #f1f1f1;
# }
# #T_2dc56_row7_col3 {
#   background-color: #06733d;
#   color: #f1f1f1;
# }
# #T_2dc56_row7_col4, #T_2dc56_row46_col2, #T_2dc56_row47_col1, #T_2dc56_row50_col5 {
#   background-color: #abdb6d;
#   color: #000000;
# }
# #T_2dc56_row7_col5, #T_2dc56_row13_col0, #T_2dc56_row16_col0, #T_2dc56_row18_col1, #T_2dc56_row31_col1, #T_2dc56_row36_col1, #T_2dc56_row48_col5 {
#   background-color: #5ab760;
#   color: #f1f1f1;
# }
# #T_2dc56_row8_col0, #T_2dc56_row21_col4, #T_2dc56_row29_col3 {
#   background-color: #219c52;
#   color: #f1f1f1;
# }
# #T_2dc56_row8_col1, #T_2dc56_row9_col1, #T_2dc56_row12_col2, #T_2dc56_row12_col4, #T_2dc56_row16_col5 {
#   background-color: #108647;
#   color: #f1f1f1;
# }
# #T_2dc56_row9_col0, #T_2dc56_row14_col3, #T_2dc56_row20_col2, #T_2dc56_row21_col2, #T_2dc56_row22_col4, #T_2dc56_row26_col4 {
#   background-color: #279f53;
#   color: #f1f1f1;
# }
# #T_2dc56_row9_col4 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_2dc56_row10_col0, #T_2dc56_row28_col5, #T_2dc56_row51_col3 {
#   background-color: #33a456;
#   color: #f1f1f1;
# }
# #T_2dc56_row10_col3 {
#   background-color: #199750;
#   color: #f1f1f1;
# }
# #T_2dc56_row11_col0, #T_2dc56_row12_col3, #T_2dc56_row13_col3, #T_2dc56_row20_col5, #T_2dc56_row21_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
# }
# #T_2dc56_row11_col1 {
#   background-color: #097940;
#   color: #f1f1f1;
# }
# #T_2dc56_row11_col3, #T_2dc56_row15_col1, #T_2dc56_row18_col2, #T_2dc56_row19_col2, #T_2dc56_row21_col3, #T_2dc56_row36_col5, #T_2dc56_row41_col4 {
#   background-color: #249d53;
#   color: #f1f1f1;
# }
# #T_2dc56_row11_col4, #T_2dc56_row56_col2 {
#   background-color: #d3ec87;
#   color: #000000;
# }
# #T_2dc56_row11_col5, #T_2dc56_row34_col4, #T_2dc56_row42_col2, #T_2dc56_row56_col3 {
#   background-color: #8ecf67;
#   color: #000000;
# }
# #T_2dc56_row12_col0, #T_2dc56_row15_col4, #T_2dc56_row16_col1, #T_2dc56_row31_col5 {
#   background-color: #1b9950;
#   color: #f1f1f1;
# }
# #T_2dc56_row13_col4, #T_2dc56_row52_col3 {
#   background-color: #b3df72;
#   color: #000000;
# }
# #T_2dc56_row13_col5, #T_2dc56_row24_col1, #T_2dc56_row37_col4 {
#   background-color: #75c465;
#   color: #000000;
# }
# #T_2dc56_row14_col0, #T_2dc56_row23_col0, #T_2dc56_row33_col3, #T_2dc56_row39_col4 {
#   background-color: #6bbf64;
#   color: #000000;
# }
# #T_2dc56_row14_col4, #T_2dc56_row25_col3, #T_2dc56_row43_col0, #T_2dc56_row46_col0, #T_2dc56_row50_col4, #T_2dc56_row52_col2, #T_2dc56_row53_col2 {
#   background-color: #c1e57b;
#   color: #000000;
# }
# #T_2dc56_row14_col5, #T_2dc56_row56_col0, #T_2dc56_row61_col4 {
#   background-color: #7dc765;
#   color: #000000;
# }
# #T_2dc56_row15_col0, #T_2dc56_row31_col4, #T_2dc56_row44_col3, #T_2dc56_row66_col0 {
#   background-color: #2aa054;
#   color: #f1f1f1;
# }
# #T_2dc56_row15_col3, #T_2dc56_row27_col3, #T_2dc56_row40_col0, #T_2dc56_row52_col4 {
#   background-color: #66bd63;
#   color: #f1f1f1;
# }
# #T_2dc56_row16_col3, #T_2dc56_row27_col1, #T_2dc56_row28_col1, #T_2dc56_row29_col4, #T_2dc56_row31_col3, #T_2dc56_row37_col2 {
#   background-color: #69be63;
#   color: #f1f1f1;
# }
# #T_2dc56_row17_col3, #T_2dc56_row27_col5 {
#   background-color: #30a356;
#   color: #f1f1f1;
# }
# #T_2dc56_row17_col4, #T_2dc56_row44_col1, #T_2dc56_row58_col4 {
#   background-color: #c5e67e;
#   color: #000000;
# }
# #T_2dc56_row17_col5, #T_2dc56_row33_col1, #T_2dc56_row37_col1, #T_2dc56_row58_col5 {
#   background-color: #82c966;
#   color: #000000;
# }
# #T_2dc56_row18_col3 {
#   background-color: #148e4b;
#   color: #f1f1f1;
# }
# #T_2dc56_row18_col4, #T_2dc56_row22_col3, #T_2dc56_row24_col2, #T_2dc56_row25_col2, #T_2dc56_row36_col4, #T_2dc56_row39_col5, #T_2dc56_row47_col5 {
#   background-color: #3faa59;
#   color: #f1f1f1;
# }
# #T_2dc56_row19_col0, #T_2dc56_row26_col2, #T_2dc56_row27_col2 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
# }
# #T_2dc56_row19_col1, #T_2dc56_row20_col1, #T_2dc56_row35_col0, #T_2dc56_row47_col4 {
#   background-color: #39a758;
#   color: #f1f1f1;
# }
# #T_2dc56_row19_col3, #T_2dc56_row32_col3 {
#   background-color: #6ec064;
#   color: #000000;
# }
# #T_2dc56_row19_col5, #T_2dc56_row49_col3 {
#   background-color: #70c164;
#   color: #000000;
# }
# #T_2dc56_row20_col0, #T_2dc56_row22_col0, #T_2dc56_row23_col1, #T_2dc56_row27_col0, #T_2dc56_row28_col2, #T_2dc56_row29_col2, #T_2dc56_row30_col2, #T_2dc56_row40_col5 {
#   background-color: #48ae5c;
#   color: #f1f1f1;
# }
# #T_2dc56_row20_col3, #T_2dc56_row38_col1, #T_2dc56_row43_col2 {
#   background-color: #98d368;
#   color: #000000;
# }
# #T_2dc56_row21_col0, #T_2dc56_row22_col2, #T_2dc56_row30_col1, #T_2dc56_row34_col0, #T_2dc56_row58_col3 {
#   background-color: #36a657;
#   color: #f1f1f1;
# }
# #T_2dc56_row22_col1, #T_2dc56_row38_col5 {
#   background-color: #54b45f;
#   color: #f1f1f1;
# }
# #T_2dc56_row23_col2 {
#   background-color: #3ca959;
#   color: #f1f1f1;
# }
# #T_2dc

# %%
# ── Distribution plots ─────────────────────────────────────────────────────────
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
fig.suptitle(f'Val set — {run_dir.name}', fontsize=11)

axes[0].hist(df['tdr_f1'],    bins=20, color='steelblue', edgecolor='white')
axes[0].axvline(df['tdr_f1'].mean(), color='red', linestyle='--', label=f'mean={df["tdr_f1"].mean():.3f}')
axes[0].set_title('TDR F1 distribution')
axes[0].set_xlabel('F1'); axes[0].legend()

axes[1].hist(df['onset_f1'], bins=20, color='darkorange', edgecolor='white')
axes[1].axvline(df['onset_f1'].mean(), color='red', linestyle='--', label=f'mean={df["onset_f1"].mean():.3f}')
axes[1].set_title('Onset F1 distribution')
axes[1].set_xlabel('F1'); axes[1].legend()

plt.tight_layout()
plt.show()

# %%
# ── Best and worst tracks ──────────────────────────────────────────────────────
n = 5
print(f'Top {n} tracks (TDR F1):')
print(df.nlargest(n, 'tdr_f1')[['track','tdr_f1','onset_f1','n_gt_notes']].to_string(index=False))
print(f'\nBottom {n} tracks (TDR F1):')
print(df.nsmallest(n, 'tdr_f1')[['track','tdr_f1','onset_f1','n_gt_notes']].to_string(index=False))
# Out:
# Top 5 tracks (TDR F1):
#                track   tdr_f1  onset_f1  n_gt_notes
#  02_Jazz3-150-C_solo 0.959459  0.972973          73
# 01_Funk1-114-Ab_comp 0.956522  0.746594         232
#     02_SS3-98-C_solo 0.951613  0.967742         127
#  05_Rock1-130-A_solo 0.951613  0.951613          60
#    03_BN3-119-G_comp 0.936387  0.562044         199
#
# Bottom 5 tracks (TDR F1):
#                track   tdr_f1  onset_f1  n_gt_notes
# 05_Funk1-114-Ab_comp 0.158996  0.227273         181
#   02_Funk3-98-A_comp 0.346939  0.325843         130
#   03_SS1-100-C#_solo 0.388889  0.554217         111
# 05_Jazz2-110-Bb_solo 0.439791  0.734043         103
#  05_Rock3-148-C_solo 0.444444  0.611111          61
